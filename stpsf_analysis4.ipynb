# %% [markdown]
# <b>This Jupyter notebook performs calculations described and used in Sections 3 and 4.3 of JWST Technical report "OTE Science Performance Memo 7: The Optimal Wavefront Control Threshold" (van der Marel, 2025, in preparation). To setup a conda environment for running this notebook, see e.g., Appendix A of <A HREF="https://www.stsci.edu/files/live/sites/www/files/home/jwst/documentation/technical-documents/_documents/JWST-STScI-009059.pdf">"OTE Science Performance Memo 5: The Optimal Wavefront Sensing Cadence" (van der Marel, 2025)<A></b>

# %% [markdown]
# ## Import Packages

# %%
# Import packages

import webbpsf
import poppy
import os
import numpy as np
import matplotlib.pylab as plt
import csv
import math

from astropy.table import Table, vstack
# Out:
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-068 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-072
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf

# %% [markdown]
# ## Define Functions

# %%
# Define a function for getting the encircled energy for a list of radii

def get_encircled_energy(psf_hdu, radii):
    """
    Calculates the encircled energy for given radii using poppy.

    Parameters:
    psf_hdu (astropy.io.fits.HDUList): The PSF object returned by stpsf.calc_psf().
    radii (float or 1D ndarray): The radii in arcseconds at which to calculate EE.

    Returns:
    ndarray: The encircled energy at each radius.
    """
    # measure_ee returns a function that interpolates the EE curve
    ee_interp = poppy.measure_ee(psf_hdu)
    
    # Call the interpolator function with the desired radii
    encircled_energies = ee_interp(radii)
    
    return encircled_energies

# %%
# Define a function for calculating the encircled energy for a given OPD file

def get_EE_rvdm(opd_fn,Ropt):
    nrc.load_wss_opd(opd_fn, output_path=output_path)
    fov_pixels = 511
    psf = nrc.calc_psf(oversample=4, fov_pixels=fov_pixels)
    fwhm_value = webbpsf.measure_fwhm(psf)
    desired_radii = np.array([Ropt])
    ee_values = get_encircled_energy(psf, desired_radii)
    return psf, fwhm_value, ee_values[0]

# %%
# define a function for reading a column from a csv file

def read_column_from_csv(filename, column_name):
    """
    Reads a specific column from a CSV file and returns it as a list.

    Args:
        filename (str): The path to the CSV file.
        column_name (str): The header name of the column to read.

    Returns:
        list: A list containing the data from the specified column.
    """
    column_data = []
    with open(filename, 'r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if column_name in row:
                column_data.append(row[column_name])
            else:
                print(f"Warning: Column '{column_name}' not found in a row.")
    return column_data

# %% [markdown]
# ## Set Variables

# %%
# Files containing such information as the JWST pupil shape, instrument throughputs, and aperture positions are distributed separately from STPSF.
# To run STPSF, you must download these files and tell STPSF where to find them using the STPSF_PATH environment variable.

# Set environmental variables
# os.environ["WEBBPSF_PATH"] = "./data/webbpsf-data"

# %%
# Set output path to current working directory
output_path = os.getcwd()

# %% [markdown]
# ## Download OPDs and extract RMS WFE

# %%
# Download the OPD files for the months of interest, and show the trend_table in each case

trend_table4 = webbpsf.trending.monthly_trending_plot(2024, 4, verbose=False)
trend_table5 = webbpsf.trending.monthly_trending_plot(2024, 5, verbose=False)
trend_table6 = webbpsf.trending.monthly_trending_plot(2024, 6, verbose=False)
trend_table7 = webbpsf.trending.monthly_trending_plot(2024, 7, verbose=False)
trend_table8 = webbpsf.trending.monthly_trending_plot(2024, 8, verbose=False)
trend_table9 = webbpsf.trending.monthly_trending_plot(2024, 9, verbose=False)
trend_table10 = webbpsf.trending.monthly_trending_plot(2024, 10, verbose=False)
# Out:
# /Users/marel/anaconda3/envs/TelTools/lib/python3.12/site-packages/webbpsf/utils.py:241: UserWarning: Environment variable $WEBBPSF_PATH is not set!
#
#  ***********  ERROR  ******  ERROR  ******  ERROR  ******  ERROR  ***********
#  *                                                                          *
#  *  WebbPSF requires several data files to operate.                         *
#  *  These files could not be located automatically at this time, or this    *
#  *  version of the software requires a newer set of reference files than    *
#  *  you have installed.  For more details see:                              *
#  *                                                                          *
#  *        https://webbpsf.readthedocs.io/en/stable/installation.html        *
#  *                                                                          *
#  *  under "Installing the Required Data Files".                             *
#  *  WebbPSF will not be able to function properly until the appropriate     *
#  *  reference files have been downloaded to your machine and installed.     *
#  *                                                                          *
#  ****************************************************************************
#  searching default location..s
#   warnings.warn(message)

# %%
# Get the object type of the trend tables 

print(type(trend_table4))

# Combine trend_tables into one, but omit the first lines of tables 6,8,10, which are duplicates
# with the last lines of 5,7,9

tables_to_combine = [trend_table4,trend_table5,trend_table6[1:],trend_table7,trend_table8[1:],trend_table9,trend_table10[1:]]
trend_table = vstack(tables_to_combine)
# Out:
# <class 'astropy.table.table.QTable'>

# %%
# Write the trend table to screen

# trend_table

# Write the trend_table to file

trend_table.write('trend_table.csv', overwrite=True)

# Read the 'RMS WFE (OTE only)' column back in as a list

column_data = read_column_from_csv('trend_table.csv', 'RMS WFE (OTE only)')

# Convert to a numpy array of float64 type

rmsWFE = np.array(column_data, dtype=np.float64)

# %%
# Calculate which rmsWFE element has the lowest value

imin = np.argmin(rmsWFE)
print(imin,rmsWFE[imin])
print(rmsWFE)
# Out:
# 7 60.632033979748314
# [62.15257494 61.78915385 61.79780681 61.9577156  61.92796414 61.89509535
#  62.05052332 60.63203398 61.63449796 61.85806181 61.98823779 61.91615433
#  61.90060404 62.49314316 62.7578714  62.65383728 62.78808591 62.25872797
#  62.98982017 62.54702489 62.75545045 62.9230276  62.74304802 63.02934058
#  63.00970052 63.3709548  63.77091226 63.582456   63.65312768 63.93035887
#  64.3005467  64.23481177 64.29193242 64.51686308 63.62144098 64.30479743
#  64.4532602  64.34161991 64.25425351 64.86571635 64.9043615  65.40644711
#  65.49678182 65.43322848 65.42029672 65.41839635 65.48025974 65.18549994
#  65.27472671 65.40838072 65.56278242 65.26025225 65.02832914 65.12358077
#  65.38161285 65.61257345 66.42025953 66.54020306 67.30727223 66.80034935
#  67.14465819 66.99511695 65.81150056 66.37410233 66.77342679 68.61431995
#  66.90312904 66.7608064  67.68432253 67.50776654 67.66146506 67.80484108
#  70.08157847 67.48856953 68.01313406 67.81706405 67.88019151 68.24925269
#  69.00618742 67.95554783 67.52954195 66.70667687 68.06073557 67.58686764
#  67.30531615 67.8422241  61.20291982 61.8934392  61.90307543 61.92956624
#  63.97153903 63.98028355 62.68794476 62.3032146  62.67291693 62.95698381
#  63.81090892 63.85054245]

# %%
# Read the OPD file names into an array

file_array_all = read_column_from_csv('trend_table.csv','Filename')

# Remove the last 12 elements, which are after the 10/03/2024 WFC activity

file_array = file_array_all[:-12] 

# Print the resulting array of file names for testing

print(file_array)

# Print the rmsWFE for the last element for testing

print(rmsWFE[len(file_array)-1])
# Out:
# ['R2024033102-NRCA3_FP1-1.fits', 'O2024040501-NRCA3_FP1-1.fits', 'O2024040701-NRCA3_FP1-1.fits', 'O2024041001-NRCA3_FP1-1.fits', 'O2024041101-NRCA3_FP1-1.fits', 'R2024041502-NRCA3_FP1-1.fits', 'O2024041601-NRCA3_FP1-1.fits', 'R2024042102-NRCA3_FP1-1.fits', 'R2024042301-NRCA3_FP1-1.fits', 'R2024042502-NRCA3_FP1-1.fits', 'R2024042702-NRCA3_FP1-1.fits', 'R2024042802-NRCA3_FP1-1.fits', 'O2024050101-NRCA3_FP1-1.fits', 'R2024050604-NRCA3_FP1-1.fits', 'O2024050601-NRCA3_FP1-1.fits', 'R2024050802-NRCA3_FP1-1.fits', 'R2024050902-NRCA3_FP1-1.fits', 'R2024051102-NRCA3_FP1-1.fits', 'R2024051402-NRCA3_FP1-1.fits', 'R2024051802-NRCA3_FP1-1.fits', 'R2024052002-NRCA3_FP1-1.fits', 'R2024052202-NRCA3_FP1-1.fits', 'R2024052402-NRCA3_FP1-1.fits', 'R2024052602-NRCA3_FP1-1.fits', 'R2024052802-NRCA3_FP1-1.fits', 'R2024053002-NRCA3_FP1-1.fits', 'R2024060102-NRCA3_FP1-1.fits', 'R2024060302-NRCA3_FP1-1.fits', 'O2024060501-NRCA3_FP1-1.fits', 'O2024060602-NRCA3_FP1-1.fits', 'O2024060801-NRCA3_FP1-1.fits', 'O2024061001-NRCA3_FP1-1.fits', 'O2024061301-NRCA3_FP1-1.fits', 'O2024061501-NRCA3_FP1-1.fits', 'O2024061701-NRCA3_FP1-1.fits', 'O2024061801-NRCA3_FP1-1.fits', 'O2024062101-NRCA3_FP1-1.fits', 'O2024062301-NRCA3_FP1-1.fits', 'O2024062401-NRCA3_FP1-1.fits', 'O2024062601-NRCA3_FP1-1.fits', 'O2024062801-NRCA3_FP1-1.fits', 'O2024062901-NRCA3_FP1-1.fits', 'O2024070301-NRCA3_FP1-1.fits', 'O2024070302-NRCA3_FP1-1.fits', 'O2024070501-NRCA3_FP1-1.fits', 'O2024070701-NRCA3_FP1-1.fits', 'O2024070901-NRCA3_FP1-1.fits', 'R2024071102-NRCA3_FP1-1.fits', 'R2024071302-NRCA3_FP1-1.fits', 'R2024071502-NRCA3_FP1-1.fits', 'R2024071702-NRCA3_FP1-1.fits', 'R2024071902-NRCA3_FP1-1.fits', 'R2024072102-NRCA3_FP1-1.fits', 'O2024072301-NRCA3_FP1-1.fits', 'O2024072501-NRCA3_FP1-1.fits', 'O2024072701-NRCA3_FP1-1.fits', 'O2024072901-NRCA3_FP1-1.fits', 'R2024073102-NRCA3_FP1-1.fits', 'O2024080501-NRCA3_FP1-1.fits', 'O2024080502-NRCA3_FP1-1.fits', 'O2024080801-NRCA3_FP1-1.fits', 'O2024080901-NRCA3_FP1-1.fits', 'O2024081101-NRCA3_FP1-1.fits', 'O2024081301-NRCA3_FP1-1.fits', 'O2024081601-NRCA3_FP1-1.fits', 'O2024081701-NRCA3_FP1-1.fits', 'O2024082302-NRCA3_FP1-1.fits', 'R2024082402-NRCA3_FP1-1.fits', 'R2024082602-NRCA3_FP1-1.fits', 'R2024082802-NRCA3_FP1-1.fits', 'R2024083001-NRCA3_FP1-1.fits', 'R2024083102-NRCA3_FP1-1.fits', 'R2024090402-NRCA3_FP1-1.fits', 'O2024090701-NRCA3_FP1-1.fits', 'O2024090801-NRCA3_FP1-1.fits', 'R2024091102-NRCA3_FP1-1.fits', 'O2024091301-NRCA3_FP1-1.fits', 'O2024091501-NRCA3_FP1-1.fits', 'R2024091702-NRCA3_FP1-1.fits', 'R2024091902-NRCA3_FP1-1.fits', 'R2024092202-NRCA3_FP1-1.fits', 'R2024092402-NRCA3_FP1-1.fits', 'R2024092502-NRCA3_FP1-1.fits', 'R2024092802-NRCA3_FP1-1.fits', 'R2024093004-NRCA3_FP1-1.fits', 'R2024100302-NRCA3_FP1-1.fits']
# 67.84222409659087

# %% [markdown]
# ## F212N Analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F212N'

# Initialize arrays for FWHM and EE values

fwhm_212 = np.zeros(len(file_array))
EE_212 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.08" (i.e., 2.5 pixels) for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.08)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD
# The EE can be compared to the one listed in the trend_table (0.6717) for testing. 
 
print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.06911486523064368 0.6738875743847198
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     104   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       106   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       158   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       159   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_212 = Ropt
print (Ropt)
# Out:
# 0.047201775694671315

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_212[i], EE_212[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_212[i], EE_212[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915657686930829 0.5274893602660201
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914376539320617 0.5278067625862192
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914554306723755 0.5278727796046603
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914307941118841 0.5278197391076329
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914771240863045 0.5278435462578391
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691464844914457 0.5279424360698214
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914786704171795 0.5278827874189312
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911486523064368 0.5287971402465715
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914703183475161 0.5283003250926501
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691426176360026 0.5281045970333961
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914097147211377 0.5281148524173324
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691446049052791 0.5280557321328698
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914674916307262 0.528089632158553
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911126195676996 0.5279553299915554
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911329335817956 0.5280654855143192
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691086579626866 0.5281532630296012
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911103603211406 0.5281188589416107
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691297155546386 0.5284372533879714
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911802683598078 0.5279716249469155
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06911839210114706 0.528010419080306
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06912126660777641 0.5277671989419906
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06912217839466622 0.52768110505449
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691444119727987 0.528124765612065
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916100123722944 0.5285049010750835
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916571001469198 0.5284790426540388
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915379389057394 0.5279983222038188
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915587213468018 0.5280711060132489
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918257252897116 0.5279225620311632
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915605660139253 0.5280815606782213
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914323587342121 0.5278044659154709
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06913798608401815 0.5275073048277763
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.069144320063051 0.5274245854727281
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915026494664891 0.527528643028864
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914541917750598 0.5273621125734781
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915480432556723 0.5277071410523219
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06914952405365649 0.5274460128709676
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918633026721743 0.5273288025158503
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915305380573927 0.5275119787389303
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915477248010973 0.5273787131459026
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916062707434849 0.5270908508152766
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915839092113087 0.5271153512210464
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917202771906683 0.5267902873827178
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917476686968238 0.5266122582955994
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691733967300538 0.5266399885879429
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917266228075214 0.5266934477731343
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917167858650293 0.5267563811514602
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916416488670614 0.5265500692847802
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916877083065158 0.5268739710019057
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917246302034583 0.5266995183112835
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918262567440572 0.5264621953164238
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06919634334050563 0.5257963480462173
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918691976451032 0.5261073162228682
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06915822796626854 0.5268828139929376
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916364288503837 0.5268756943427023
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916468351831898 0.5267417500687854
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916801289527165 0.5266356921015002
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06919184048485938 0.5254566268657983
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06919704060289963 0.525499788594694
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06921371547787374 0.5247083309692697
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06920494971761662 0.5250251120894084
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06921285305083388 0.5247561756801581
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06920733983290116 0.5247295053284013
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917345443858842 0.5258581332747243
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918415718767933 0.5252561457884225
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06920066779969826 0.5251074425870601
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06923460761063435 0.5240622058308463
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691767968541126 0.5257037956232077
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917145782629903 0.5257017867640154
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691846233385981 0.5252040418589948
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918082173253129 0.5252548076729451
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918565392601936 0.5252426316328792
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918813792979307 0.5251269945428393
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06920815166653937 0.5234485378029259
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917022103939742 0.5247437901877214
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917084317488227 0.5243138890054958
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917882783240242 0.5243823406696897
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.069180295583808 0.5244437289068675
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06917875941336953 0.5239990943814783
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918886282373414 0.5234530890223955
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06916993580202702 0.5240600219943998
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918485250601777 0.524301306276007
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691856482114999 0.5249544223677938
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06919303050063723 0.5231121826196433
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06918221130713192 0.523048847036157
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0691767150943364 0.523500616440322
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.069191424362516 0.5230949484308874

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_212, EE_212)

# %% [markdown]
# ## F070W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F070W'

# Initialize arrays for FWHM and EE values

fwhm_070 = np.zeros(len(file_array))
EE_070 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.02279252518159875 0.6419383736538892
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_070 = Ropt
print (Ropt)
# Out:
# 0.01742254182782119

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_070[i], EE_070[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_070[i], EE_070[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022845226318770083 0.4120198624313481
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022801141918295777 0.4148346321468238
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022805302997980993 0.415211137947719
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022804914126436964 0.4146026295235241
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02281676004816034 0.41479086775024315
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022811507933046586 0.4156242344177991
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0228165013611001 0.41524443908681646
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02279252518159875 0.42127111386676175
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022814638180837014 0.41859545304649953
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022800273582558695 0.416964960111658
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02279565850176797 0.41710679521143795
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022807972585396973 0.41621768412694166
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022814646249076073 0.4168679292707971
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02279041801229902 0.41572847367848215
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022799225760239888 0.41661222275602305
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022776320472903906 0.4173901764440372
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022787579195448632 0.41685163803915726
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02285776911834861 0.41867941083164856
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022818299240606365 0.4161189549524968
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022815693467643935 0.4162185857301021
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022830491822107477 0.4140244917317016
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02282855718708514 0.4135027980452146
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022816043224024845 0.4168582952000987
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022780614848354013 0.4199722048324388
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022795825235213167 0.4195699990020157
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022843670820373172 0.416101565534034
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02284538395873258 0.41720929589495653
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022841089785982586 0.4155664705414201
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02284426277055822 0.41716285858563995
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022865809268121637 0.41476190734924256
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02288560254572198 0.4126154654807943
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022917302965132082 0.41221285455994844
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022888464950334097 0.41330940343091954
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022921165427514347 0.4117366118039468
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02291118170992854 0.4135192073724015
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02288365435653811 0.4122719985630096
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023013733891337342 0.411785077001642
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023028135822358436 0.41354029744900234
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02303363906806498 0.4122295846288236
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02304988847561212 0.41048215660111864
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023042923035929183 0.41093709518946275
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023127333019525673 0.4087819633895398
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023138642360941847 0.40743803587234606
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02313016564262084 0.4072138135788366
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023097073912898666 0.407588968069058
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023090574124127666 0.4079372584377204
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02313763260682644 0.4062856216445597
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023078561254262296 0.40877073727041907
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023094558515879614 0.4073060068725848
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02303549525761572 0.40580096623948075
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023079942900979644 0.4005559791621787
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023048562629665516 0.4029120167167142
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.022987421652816472 0.4088745295538999
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023129437873251127 0.40909656547327317
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023135903959138192 0.4080986765946322
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02314898666782572 0.40744289849598364
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02314773300403204 0.3993215277455824
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023169311232708486 0.4000799908824557
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02324368726318456 0.39454277887350253
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023207864958123655 0.39633639533605647
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023237521716288522 0.39447258624598464
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02321687770923148 0.39410843511863236
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02307941502866528 0.40191440615549595
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02312662138624302 0.39759041209014234
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02311789288688582 0.3960268992591545
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023297367845172206 0.3902081821420322
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023054183462223227 0.40041557175178294
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023075025821343943 0.4004216556378544
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02312538829758073 0.39743348906992665
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023109467502667284 0.3975366781879101
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02312802037664492 0.3975308870082977
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023133589106722606 0.3967308676968823
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023279209042410414 0.3855808759935004
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02314799173149964 0.3935419540070048
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023182948498326524 0.390922918414204
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023167655495130942 0.3913071181533411
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023172869504359057 0.3916399555828842
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02321125970235417 0.3884542425818291
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02315799707211711 0.3850610930358567
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02304954975302156 0.3883926537770985
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02309050428577278 0.3898065399649505
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023049196654097336 0.3945045563934608
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023114468654566546 0.38224199742755344
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023077134833381148 0.3810223935875506
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.023058640984840176 0.38427599130875034
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02311487035922186 0.3817946076213219

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_070, EE_070)

# %% [markdown]
# ## F090W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F090W'

# Initialize arrays for FWHM and EE values

fwhm_090 = np.zeros(len(file_array))
EE_090 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.029451428624575393 0.6310895027517045
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_090 = Ropt
print (Ropt)
# Out:
# 0.022033625608343644

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_090[i], EE_090[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_090[i], EE_090[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029492416242189394 0.4889659574666143
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02946437326096299 0.4910074566112971
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02946999907883525 0.4914183560510577
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02946653593191097 0.4907635640136156
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029479139864262496 0.4910871038312899
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0294706764988655 0.49174471314927465
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029472482025803597 0.49150298029493683
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029451428624575393 0.49631833838809625
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029475043562300646 0.49422351214246885
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029462534199001005 0.49295114714012755
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029462626059423007 0.4931265479825573
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02947972948515449 0.4922592529475351
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02947768950893345 0.4926827337900195
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02944360511041004 0.4919099601089259
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029447194599834307 0.4927997786527089
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029432185567888926 0.49322102000840573
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029449922459788645 0.492895310813458
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029493076956675985 0.4944933209326754
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029467481098717906 0.4924956652995625
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029472895492376684 0.4925480636036743
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029486541392876275 0.4906670851453878
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029491851094590408 0.49029488735532867
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02947342597487105 0.49316047563302196
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029444070178074586 0.4956399607865033
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029459029362865975 0.4952164489744602
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0294998238351546 0.4925346536871689
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029486025700962117 0.4939018900324774
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02949506190359531 0.492332849933941
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029486748876352657 0.4937420861068313
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029515981050442563 0.49196624078759427
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0295442094106383 0.4902972568356326
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02954896116277979 0.49001834408203293
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02952993529066279 0.4909470480335839
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029550346497608973 0.48979638454157703
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029545205285727176 0.4909334716298286
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02953285590484678 0.4901557467666155
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029579572692325216 0.4896607707495372
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029566104187606662 0.4913406280018094
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02957469731386488 0.49016918022836087
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029587605090730308 0.48906620005145307
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029581292123818187 0.48942459019520934
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029619691890887253 0.48771521295119696
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02962407777077929 0.4866352200223239
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029623735400669406 0.4863998080870552
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029623001677712018 0.48674771266427874
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029620703548089444 0.48702745585740154
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02963656255343124 0.48559290403922345
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029612397381507696 0.487627661063761
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029627725901605156 0.48640710378680646
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02965116863817737 0.48537949981457595
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029693769613230687 0.48125170527676014
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029664023447242886 0.4831436478438553
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02960605527618976 0.4878465263543439
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029621038499846278 0.48792411954167003
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02962708657159009 0.48721946611583733
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02963233037910097 0.4867964891226359
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029698611247735866 0.48025613037606746
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029702552425243438 0.4811068803512056
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029759181766590582 0.4766429912625373
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029734348849764933 0.4780350073706514
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02975939686898497 0.47639631091538964
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02974305009302689 0.4760327561491981
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0296170278815665 0.48215749107052436
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02965617184271192 0.47870074950784525
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029664392644723328 0.4770759933624329
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029777264126599187 0.47303268984845276
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02957392058603138 0.4808531337214726
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029592592895849604 0.4808351512312157
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029632331105464732 0.4787788418410385
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029627651647800308 0.47875284701072474
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02963744800173822 0.47886381126887734
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02964708408395776 0.4783117735142025
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029733097412809214 0.46976870545159777
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029573111645847847 0.4755273923762317
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029597912919954762 0.47385903878644664
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029591071631054063 0.47403901662915066
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02959690806439408 0.47445622892583333
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02962110916345672 0.4718937935516503
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029652563664675807 0.4691931837581315
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029605279963677556 0.47165818755889993
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02956658148124851 0.4727509312879078
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029535707846462717 0.47644422728746055
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029658126777383075 0.46693371281827256
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.029641621801346954 0.4657880829324506
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02962079280090605 0.46856509003788027
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.02966038463629614 0.46658238909695704

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_090, EE_090)

# %% [markdown]
# ## F115W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F115W'

# Initialize arrays for FWHM and EE values

fwhm_115 = np.zeros(len(file_array))
EE_115 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.03718515351829068 0.6329480192231296
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_115 = Ropt
print (Ropt)
# Out:
# 0.02724979841561603

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_115[i], EE_115[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_115[i], EE_115[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03721229449176037 0.5471735335792773
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718170769601774 0.5481245776539823
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037181364698413974 0.5479906789992101
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037175371855291565 0.5483604335855345
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0371829143043718 0.548157937017735
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037184236429947976 0.5483631770568455
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718605124370028 0.5478166747717946
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718515351829069 0.5497723089026361
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03717390517679847 0.5486679286109246
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03716998836511082 0.5482544572260789
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03717774037788397 0.5479086272455163
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718140878043558 0.5485213784924087
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03717400161600634 0.5487604927179219
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718741491537734 0.5476595264060546
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718924536639431 0.5473897848786514
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718339984347144 0.5478612706608524
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037177199458447406 0.5478011729391205
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03720979084699285 0.5482835511637529
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037187612133134595 0.5469704553231112
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718504678808946 0.5473545810810704
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718775597162912 0.5471366071816138
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037186875950084054 0.5469139228192603
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718370354040989 0.547344531679408
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03716499142877119 0.5477715936468448
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0371723077705685 0.5482092550261132
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03717691931377021 0.5471041733684116
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03719087642959653 0.5458368901490165
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03718830166602855 0.5463245773536259
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037192679604462923 0.5461378293251596
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03719552907817936 0.5455503418048269
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03720120984077136 0.544856232924478
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03722631987341823 0.5445396684215379
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037216147398390784 0.5443776532534923
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037226728215131115 0.5439840822925887
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037219792303543116 0.5454432085150438
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03721043017009839 0.5441842030980197
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037235276758974464 0.5443714196586064
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037239853614866585 0.544020449806929
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037244312905610706 0.544175486631683
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037258532600780755 0.5425500863865632
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037256851570148894 0.5425159219846367
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037286675168816175 0.5419188874830324
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037297835418622756 0.5415191327165179
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03729163925416463 0.541850560239615
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03728643923689011 0.541822894596773
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037282542748015145 0.5419669087341316
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037290167216052064 0.5419474056293448
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03727683337171753 0.5422966363728435
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03727935078472362 0.5422892397020219
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037297904498570865 0.5413355906565954
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037322595256448536 0.5401581801071856
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03730804826287193 0.5407336242148809
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03727718229994265 0.5419908250858387
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03728753259409117 0.5421429819364386
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03728743155744437 0.5415398604055744
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037298993620285326 0.5411547183264165
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03736727679562207 0.5383454236264726
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037380692441890115 0.5378203434836575
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741616426323164 0.5362269460474395
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037398972417765367 0.5371517311903472
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037413329018893354 0.5367888841605499
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03740864217284373 0.5368659179143132
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03735250096455528 0.5394771047118143
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0373794272826543 0.5381748469705588
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037388636743754845 0.5387779323415238
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03744302795895896 0.5344513731539381
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03735934221986417 0.5388144829832403
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037376041895420875 0.5389300221426712
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037409618367568065 0.536797651153088
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037399888822781564 0.5372815812015598
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741240788129186 0.5369568582764818
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741398323864709 0.5365316423375256
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03750207047766969 0.5315443725747485
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03739877776831317 0.536253573158083
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03742363251891337 0.5343117844309222
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741756786091558 0.5348206168113541
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741162197930643 0.5345635758090433
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03743481896611776 0.5336861794741665
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03745988433314182 0.5323002906919695
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03741306809517748 0.5343739383436207
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037390068729453454 0.5350137478588147
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03736123225566368 0.5366092209690038
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03742766502644106 0.5318933566928787
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03740088548837556 0.532369650919029
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.037390554563943926 0.5330127227829851
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.03742011933412911 0.5320708967169775

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_115, EE_115)

# %% [markdown]
# ## F150W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F150W'

# Initialize arrays for FWHM and EE values

fwhm_150 = np.zeros(len(file_array))
EE_150 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.04833295033902534 0.6446266063531774
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_150 = Ropt
print (Ropt)
# Out:
# 0.03450544911927581

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_150[i], EE_150[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_150[i], EE_150[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04838385188028334 0.5359735305273192
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835686256076926 0.5364125075188156
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835693400774141 0.5362696433542914
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835286074643032 0.5366458654116599
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835693873030405 0.5364405089266181
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04836057286081119 0.536498347194462
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04836304818636711 0.5361372573578016
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04833295033902534 0.5370628660824575
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048326497895336766 0.5364313087629636
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834698033448239 0.5362676920087233
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04831905966875853 0.5359960061034599
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048317984322379846 0.5365848359765346
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834611491784694 0.536693571675642
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835625685333833 0.5359725140015287
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834134926289994 0.5356592679772737
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04833757661355741 0.5359575173707023
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832458777182717 0.535971376940898
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04833691259943048 0.5361852538283868
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04833446527314073 0.5353800394383527
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832757853409927 0.5356721072131739
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048324629448659874 0.5357827478670321
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832211939490016 0.5356604409798681
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832637947829847 0.5356063609853184
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04829593995422278 0.5356002734888373
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04829977439141715 0.5359867521396171
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048308255934180123 0.5355108347554923
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832539585480796 0.5343454740660281
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048318562353212066 0.5349409682844628
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834348466449065 0.5345981359917188
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048340282575773594 0.5343939161493585
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04832034485128674 0.5340951137280423
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834354691966818 0.5338742569184055
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048340318336255135 0.5336144568169515
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834469833819058 0.5334778593185342
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04835723265947518 0.5345044203553949
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048333561228772186 0.5335929557413713
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048340256444217536 0.5338022652988363
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04834878166386033 0.5332893117142735
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04836704693163745 0.5335750242691354
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04838092818470658 0.5324686754789778
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04838166320867784 0.5323738552849039
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048419601300677094 0.5321392197702142
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048428379958104915 0.5319755778169515
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04840169546816017 0.5322859535808352
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04839795722092939 0.5322127807953226
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0483932142058075 0.5322960871834203
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048395398668871485 0.5324768644849838
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04839164841742596 0.532470973051936
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048387765982156966 0.5326323151688329
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048400284710136306 0.532048956589144
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048409071190475876 0.5317233063835225
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04840256038326604 0.5318926415627976
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048373723953483716 0.5322162230985972
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04837669935115106 0.5323263562984825
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048376996492063985 0.5319594583116182
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04838507722014318 0.5317062914976277
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04848015764788361 0.5304318154066677
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04849801374908925 0.5298897229775905
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04852073679266609 0.5292782183257451
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048507627678496035 0.5298064609786777
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048517186266285095 0.5297585826792061
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048517478387055786 0.5298686057530252
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04848943236594216 0.5310238315765715
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048510764063388896 0.5304846971183516
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04851541623321701 0.5312060291610214
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048589804725202225 0.5284046373173675
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04850611853491855 0.5306948991885083
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04852085930921015 0.5307882242375882
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04854895569171884 0.5293903645262016
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048538913377599344 0.5297710704340577
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048550393936052615 0.5294989615638207
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04855034880751266 0.5292498554827991
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0486252250625822 0.5265146440077914
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04854100027450869 0.5293767604367162
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0485589789896918 0.528065123368198
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04855292281427147 0.5284313375408123
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04854587258382434 0.5281970829870815
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04856508117751504 0.5278564259046272
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04858565519537463 0.527134578982798
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04854657197083758 0.5284429880808595
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04853154575757462 0.5287784163554808
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048506151045101684 0.5295214882568218
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04854845992223699 0.5271685408868082
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04852291444960762 0.5277237023604563
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.04851821003072528 0.527829257474545
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.048540514255577726 0.5273658275856014

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_150, EE_150)

# %% [markdown]
# ## F200W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F200W'

# Initialize arrays for FWHM and EE values

fwhm_200 = np.zeros(len(file_array))
EE_200 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.06353565709485373 0.5889323130894829
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_200 = Ropt
print (Ropt)
# Out:
# 0.043899327903525374

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_200[i], EE_200[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_200[i], EE_200[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06357430320131709 0.528948856829269
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355900652151611 0.5292725946945844
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06356060619602417 0.5292901911378532
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355650201864887 0.5293373012861491
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06356142350567397 0.5293081663371921
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06356175693773164 0.5293898395938481
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06356379401347434 0.5292694930328683
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353565709485373 0.5301423465427262
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355926387673778 0.5296346310206729
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355637199336509 0.5294566125202574
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355323966360206 0.5294058049889133
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353231177209785 0.5294970504603456
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355825441496182 0.5295411057116284
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353444916592302 0.529286367971797
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353812408545104 0.5292961538886675
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353347425379859 0.5294254736209135
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353176593603728 0.5294069522429599
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355236179940053 0.5296908053648407
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353898718340427 0.529167063199738
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353665002237129 0.5292608698902486
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355901281910568 0.5291164431548312
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0635590030347673 0.5290263619682406
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06355943041184674 0.5293316173696379
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06352873877381919 0.5296033960636345
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06353171984085912 0.5296712918211417
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06358733901368317 0.5292216042666209
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06359713407897681 0.5290080148082223
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06359314432580061 0.529039516604493
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06359710536742944 0.5290737642248478
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06359956071646831 0.5288313444040308
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06360244040480224 0.5285526272345342
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06361413900518514 0.5284395786502682
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0636103267687058 0.528453956601616
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06361553977575088 0.5283063931633909
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06361203313784203 0.5287939014749365
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06360767747423496 0.5283943010407326
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06361801048749462 0.5283553016989246
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06362246728314841 0.5283661093478333
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06362284342576173 0.5283376785198971
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06363282166094812 0.5278804239738738
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06363179088663062 0.5278740060726865
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364615414970701 0.5275862638019035
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06365019279686832 0.5274210787752327
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364670611554145 0.5275155662498097
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0636452469055083 0.5275366788238557
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364326828367674 0.5276024064332354
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364549726994795 0.5274956496630163
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364077120790954 0.5277264444648387
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364117047409477 0.5276385196775424
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06365209971469517 0.5273363860133047
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0636634370000993 0.5267875017150346
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06365584269202404 0.5270460727455232
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364160497015743 0.5276751043782154
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364533896748793 0.5276942795407227
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06364670066201998 0.5275165561517843
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.063674960389593 0.5273806007250074
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06370714285070739 0.5262467982912749
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06371666181055227 0.5261505981763803
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06373279239816267 0.5254458619362162
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372296307904818 0.5257947054145421
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06373030860496944 0.5255926692009154
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372663557102944 0.5255992696377002
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0636974412057189 0.5266671073054805
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06370977537967454 0.5261135367484597
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0636902861474596 0.5261746523520868
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06376901784045992 0.524784220520001
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06367430589614677 0.5264863124181706
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06368173644193903 0.526505050048751
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06369932493140841 0.5258274548402027
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06371645442461822 0.525951258508468
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372327436702746 0.5258802935753523
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372517502237761 0.525741779391096
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06380404472758315 0.5239145327015299
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06374366942537707 0.5254945284715178
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06375834231465205 0.5248849030814368
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06375438306403203 0.5250165977016166
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06375366190651419 0.5250110668992861
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06376500446965384 0.5246140114475231
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06377751055723023 0.5240554538087786
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06371784359648902 0.524794825945278
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06370440993872771 0.5250436229683649
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06369114447367936 0.5256815429244932
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372800267808615 0.5238270316786864
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06371272538770292 0.5239146854571555
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06370909093980481 0.5242596460795355
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.06372431435472922 0.5238619330578236

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_200, EE_200)

# %% [markdown]
# ## F277W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F277W'

# Initialize arrays for FWHM and EE values

fwhm_277 = np.zeros(len(file_array))
EE_277 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.08831738723971669 0.46420001408239586
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_277 = Ropt
print (Ropt)
# Out:
# 0.05797306495875029

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_277[i], EE_277[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_277[i], EE_277[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832499426049052 0.5296661930167185
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831966597262429 0.5296188376062486
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831884491108337 0.5295465795523564
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831031480083795 0.5297447538970208
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831012686993865 0.529713854102081
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831361801055929 0.5296425302873918
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883137237175206 0.5295602759745454
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831738723971669 0.5295964765791895
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883058486394361 0.5294433297814705
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830528581181164 0.5294541329422772
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830541430396777 0.5292779228828347
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830325842465193 0.5295801732419986
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830428820153616 0.5296061887269994
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832216839603309 0.529048265216404
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832652637150336 0.5287974587500546
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883230290812586 0.528929987867314
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831795744440342 0.5288778977619306
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832023509566327 0.5290599862993265
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830897594107612 0.5288938105739642
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830855922956435 0.528996032734815
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830849215856043 0.5290673989190575
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830992701206129 0.5289796821888824
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883160561782256 0.5287240544616103
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832367471165173 0.5283138119900342
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832255342252468 0.528461207000783
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08830545133281688 0.5287130774018836
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831878385300981 0.5280919946823527
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831670738140457 0.5284511382836158
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832083353714858 0.5281738283845961
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831626453934069 0.5282013109247423
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883136054990135 0.5282189034243854
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831501628717228 0.5283075331201491
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831748220609777 0.5281008206700418
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831955249624475 0.5281120572203709
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831753403788155 0.5285003337993058
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831904630423895 0.5280630058223573
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831089732223377 0.5283244501765471
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883142702659649 0.5280396478769489
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08831369555344255 0.5282713459953041
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832226133942686 0.5278880376277608
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832339045773475 0.5278470726120238
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883266023307258 0.5279240187531362
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832930437829731 0.5279158343026014
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832942872570787 0.5279868869980813
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832626297260664 0.5278898711566352
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832599951407662 0.5278678666441776
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832428329221499 0.528054187628858
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832384702937819 0.5279394036932934
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832129250195968 0.528075385122493
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832370783487956 0.5279692115146695
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832601267345956 0.5280946799268127
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832377939191338 0.5279930452910914
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832366031747006 0.5278103483456368
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08832601695248525 0.5277276217722726
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.088328052019082 0.5275701875677645
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08833093899124755 0.5274885096079942
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08833776129479178 0.5277804788473246
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08834276134703557 0.5275819792655713
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08834405127039545 0.5277227398752045
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08833983455166304 0.5278835876611561
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08834519156947489 0.5279043686705845
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08834633805431505 0.5279986954580206
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08834807050120237 0.5278834915024233
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08835193971265551 0.5279516953093107
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883582622003367 0.5281455826466229
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.088395946078268 0.5271242534001112
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08836411387523377 0.5275380729493389
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08837083083589811 0.5276672392270542
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838450123012283 0.5272281784906799
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883793087228926 0.5274096945020805
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838419945560574 0.5272831460365086
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838556889738208 0.5272351482132943
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0884120292806544 0.526923457845942
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838413641827124 0.5277243421255686
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838870332311971 0.5273864301871065
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838974159616951 0.5274782543091387
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838664636979769 0.5273550503773441
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08839247149890236 0.5274492819132162
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08839629829341054 0.5273679996753802
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.0883865869293443 0.5276561804147101
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08838456358664624 0.5276553780804356
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08837892223851054 0.5277218585393376
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08837536912547814 0.5278081026813897
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08836771141101912 0.5280844029669729
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08836864145587116 0.5278928218649178
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.08837308913928146 0.5279037963107334

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_277, EE_277)

# %% [markdown]
# ## F356W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F356W'

# Initialize arrays for FWHM and EE values

fwhm_356 = np.zeros(len(file_array))
EE_356 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.11429686086268903 0.3275707407213807
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_356 = Ropt
print (Ropt)
# Out:
# 0.0710779137717131

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_356[i], EE_356[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_356[i], EE_356[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430257747301201 0.48651933887893395
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429622874957926 0.48644843050469994
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429455432776818 0.48636623426642867
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428675363216624 0.4865614247019829
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428602766362839 0.48650221778205593
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429198938336702 0.4864278306580929
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429211753060335 0.4863504031509175
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429686086268903 0.4862236724690275
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.114280849544363 0.48618688198523613
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.114283288060913 0.48623202646764674
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428043630069551 0.4860916234312768
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427470380634705 0.4863890275384079
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427915814583016 0.4863981455709651
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430325104676013 0.4860160290709824
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1143069652327108 0.48578420238192677
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430605862461084 0.48587458042623416
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1142945842106153 0.4858722456116661
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427432244307571 0.48592047612179834
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428707108075871 0.48583275027676875
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428367252869412 0.48592762321839633
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427957639395438 0.48609144188466513
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427872819554113 0.4860505644408986
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428889282974992 0.4857321456831286
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429666896177418 0.4853623193209521
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427065329966335 0.4855205819693463
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425202435023457 0.4857632329870972
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1142478494118371 0.48517357138506484
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426558452995988 0.4855432099869485
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429646370934404 0.48526443908038575
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426369819805125 0.48535383569893215
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11423360431269462 0.48542570498590515
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11424231030400261 0.4854528720468021
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11424573360943706 0.4852505110321365
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11424564562226577 0.4853017718959475
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426548170955073 0.4855944739870015
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11424438730600193 0.48526970425369403
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425611390489956 0.48549023893007587
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426442529788651 0.48516099488997294
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426262432410643 0.48539725656017374
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427315801234726 0.4850899340230838
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427626665661081 0.48503457089018565
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427875371111107 0.48514990302173583
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428273112689198 0.48517711582949113
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11428048056115178 0.4852753931332048
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427676128223137 0.48518920581364305
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427584304794003 0.48517416577126277
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427271391858268 0.4853857913365554
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11427412615883888 0.4852030249030834
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426773834748398 0.4853740946732642
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426864311053601 0.48530246179316144
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426500964527567 0.48556693350372504
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11426738750309798 0.48541795253873465
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425053603823992 0.4850829514368941
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425290087382975 0.4850610845232434
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425406298544484 0.4849622770907928
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11425890590148646 0.48490074554374263
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429404995858036 0.48526589644318174
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430235950714952 0.48503198951276666
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1143017536901727 0.48529488015569133
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11429815176653212 0.48536826925860077
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430036414026869 0.4854753360907067
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11430422475145587 0.485557368160316
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1143147693366907 0.4852698283894945
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11431900499311368 0.4854309217313598
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11431948851663543 0.48573747870181033
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11435506838340453 0.4850377241814221
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11434073065222648 0.4850781167577484
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1143488350002631 0.48516421124619263
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11436353767835014 0.4848398797882699
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1143571345653398 0.48499153800276906
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11436404655004039 0.48487561883640257
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11436312634858418 0.4848489007718604
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439655604579822 0.4847826609856799
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439223828777785 0.4852711323281532
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439713326230695 0.4849932735268781
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439727484278303 0.48508381323607364
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439094179715292 0.4849607793534399
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11439667093208333 0.48511443954131883
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11440142457539197 0.48513045914480935
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11438735774230316 0.48532493926769227
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11438907454990432 0.4852924022806058
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11438187610175034 0.48522750025725636
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11437007561089658 0.48553642145462944
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11435852967327208 0.4858343736987478
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11436215875113635 0.48556952919751
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.11436500274156504 0.48563970363990866

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_356, EE_356)

# %% [markdown]
# ## F444W analysis

# %%
# Set the instrument and filter

nrc = webbpsf.NIRCam()
nrc.filter = 'F444W'

# Initialize arrays for FWHM and EE values

fwhm_444 = np.zeros(len(file_array))
EE_444 = np.zeros(len(file_array))

# %%
# Calculate the PSF, the FWHM, and EE within 0.05" for the for the OPD with minimum WFE.

psf, fwhm_value, ee_values = get_EE_rvdm(file_array[imin],0.05)
# Out:
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)

# %%
# Show PSF results only for this first OPD

print(fwhm_value, ee_values)

# Get info on the psf object

psf.info()

# Then display the PSF and plot the encircled energy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
webbpsf.display_psf(psf, colorbar_orientation='horizontal')
axis2 = plt.subplot(1, 2, 2)
webbpsf.display_ee(psf, ext=1, ax=axis2)
# Out:
# 0.14035144152726098 0.23891545960928232
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     140   (2044, 2044)   float64
#   1  DET_SAMP      1 ImageHDU       142   (511, 511)   float64
#   2  OVERDIST      1 ImageHDU       194   (2044, 2044)   float64
#   3  DET_DIST      1 ImageHDU       195   (511, 511)   float64

# %%
# Calculate the optimal aperture radius based on the fit to the Savino et al. (2024) table

Ropt = 0.0008 + (0.7578 * fwhm_value) - (1.2505 * (fwhm_value**2))
Ropt_444 = Ropt
print (Ropt)
# Out:
# 0.08252531420231378

# %%
# Now calculate the PSF, the FWHM, and EE within Ropt for all OPDs

for i in range(len(file_array)):
    psf, fwhm_444[i], EE_444[i] = get_EE_rvdm(file_array[i],Ropt)
    print(fwhm_444[i], EE_444[i])
# Out:
# Importing and format-converting OPD from R2024033102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14032089604396042 0.459965222603872
# Importing and format-converting OPD from O2024040501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403453572478365 0.45993918786270416
# Importing and format-converting OPD from O2024040701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034554511311817 0.45990812197640485
# Importing and format-converting OPD from O2024041001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14033912443697882 0.45999301168444623
# Importing and format-converting OPD from O2024041101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403398455101556 0.459976050969389
# Importing and format-converting OPD from R2024041502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403437401521486 0.45994308554409663
# Importing and format-converting OPD from O2024041601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034467415732552 0.459910687752208
# Importing and format-converting OPD from R2024042102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035144152726098 0.4599003009291639
# Importing and format-converting OPD from R2024042301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034017721870684 0.4598529756088642
# Importing and format-converting OPD from R2024042502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14033974644850128 0.4598637607307154
# Importing and format-converting OPD from R2024042702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034040807177614 0.4597959466682275
# Importing and format-converting OPD from R2024042802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403360986826356 0.4599249636976278
# Importing and format-converting OPD from O2024050101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14033734364318923 0.4599314797257261
# Importing and format-converting OPD from R2024050604-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035382331932184 0.4597253338516478
# Importing and format-converting OPD from O2024050601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035932983438515 0.4596212692689783
# Importing and format-converting OPD from R2024050802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035718809064743 0.4596701469095212
# Importing and format-converting OPD from R2024050902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035252982147547 0.45965896660995864
# Importing and format-converting OPD from R2024051102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035679832604256 0.459719860008164
# Importing and format-converting OPD from R2024051402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034829321618997 0.45965875227840974
# Importing and format-converting OPD from R2024051802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034464126372567 0.4597005292560976
# Importing and format-converting OPD from R2024052002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034092750854707 0.45975101130371154
# Importing and format-converting OPD from R2024052202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034117392256135 0.4597205603051066
# Importing and format-converting OPD from R2024052402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035007074588549 0.45959883789309475
# Importing and format-converting OPD from R2024052602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403585470995049 0.4594282795169032
# Importing and format-converting OPD from R2024052802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035655851978568 0.45949345190500224
# Importing and format-converting OPD from R2024053002-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034172818674814 0.4596054679283037
# Importing and format-converting OPD from R2024060102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403987892262038 0.4593428765296476
# Importing and format-converting OPD from R2024060302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039336080804254 0.45949990063591345
# Importing and format-converting OPD from O2024060501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039876110945632 0.45938063887738345
# Importing and format-converting OPD from O2024060602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039341493087112 0.45940557642604957
# Importing and format-converting OPD from O2024060801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14038911905245466 0.45942310239008527
# Importing and format-converting OPD from O2024061001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039238208881094 0.4594490585967755
# Importing and format-converting OPD from O2024061301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039615439937903 0.45936047979950145
# Importing and format-converting OPD from O2024061501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039623633537415 0.4593738485862637
# Importing and format-converting OPD from O2024061701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039298005217538 0.45952663626594953
# Importing and format-converting OPD from O2024061801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039586189404177 0.4593567667387172
# Importing and format-converting OPD from O2024062101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403864173306057 0.4594608082671455
# Importing and format-converting OPD from O2024062301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036524683135113 0.4593290127942381
# Importing and format-converting OPD from O2024062401-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036246432051624 0.4594308434786892
# Importing and format-converting OPD from O2024062601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403700162019134 0.45927873792182683
# Importing and format-converting OPD from O2024062801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037176637170892 0.459257539047548
# Importing and format-converting OPD from O2024062901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034448782024542 0.4592962204597384
# Importing and format-converting OPD from O2024070301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034625581637475 0.4592980884937598
# Importing and format-converting OPD from O2024070302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037260323851222 0.4593358240751351
# Importing and format-converting OPD from O2024070501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037085511615308 0.45929727048749713
# Importing and format-converting OPD from O2024070701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037095332597055 0.4592900971863661
# Importing and format-converting OPD from O2024070901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036731055658236 0.4593741165128179
# Importing and format-converting OPD from R2024071102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036979552159 0.45931354344625513
# Importing and format-converting OPD from R2024071302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403652551993603 0.4593782880320566
# Importing and format-converting OPD from R2024071502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036717677916075 0.4593398531991608
# Importing and format-converting OPD from R2024071702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403364751948129 0.4594192892467287
# Importing and format-converting OPD from R2024071902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14033782432937342 0.4593668094074362
# Importing and format-converting OPD from R2024072102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403712277940397 0.4592597639657422
# Importing and format-converting OPD from O2024072301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403723180570213 0.4592362299821846
# Importing and format-converting OPD from O2024072501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037370817610767 0.4591801579672269
# Importing and format-converting OPD from O2024072701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037632972740202 0.45914662645106985
# Importing and format-converting OPD from O2024072901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035148548339654 0.4592855266835914
# Importing and format-converting OPD from R2024073102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035809755686188 0.45919235992966956
# Importing and format-converting OPD from O2024080501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035542925939506 0.45927495517678035
# Importing and format-converting OPD from O2024080502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403526029778707 0.4593297869061545
# Importing and format-converting OPD from O2024080801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14035417073816783 0.4593544907818129
# Importing and format-converting OPD from O2024080901-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403550406745504 0.45939271565889767
# Importing and format-converting OPD from O2024081101-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036225708042188 0.45930997412830527
# Importing and format-converting OPD from O2024081301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036275522927655 0.4593555189376576
# Importing and format-converting OPD from O2024081601-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039162253153167 0.4594614570348809
# Importing and format-converting OPD from O2024081701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039310129472754 0.45907610158437867
# Importing and format-converting OPD from O2024082302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14040507997284304 0.4591908691116262
# Importing and format-converting OPD from R2024082402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403815669351548 0.45923729391630846
# Importing and format-converting OPD from R2024082602-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039287772786577 0.45906647120035987
# Importing and format-converting OPD from R2024082802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403873346644919 0.4591387143743338
# Importing and format-converting OPD from R2024083001-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039228818080843 0.45908655912900453
# Importing and format-converting OPD from R2024083102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039259188061198 0.45906935865459714
# Importing and format-converting OPD from R2024090402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14038298781665576 0.4589743242140555
# Importing and format-converting OPD from O2024090701-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403879521912375 0.45926349069012695
# Importing and format-converting OPD from O2024090801-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403910737244955 0.45912716636382533
# Importing and format-converting OPD from R2024091102-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039062190657114 0.45916559293224113
# Importing and format-converting OPD from O2024091301-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14038852476252084 0.4591144285188621
# Importing and format-converting OPD from O2024091501-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039076638849998 0.45916543636821605
# Importing and format-converting OPD from R2024091702-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14039295577305572 0.45914599641047127
# Importing and format-converting OPD from R2024091902-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14038435812581096 0.4592570198438945
# Importing and format-converting OPD from R2024092202-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14034271855776342 0.4592506820177007
# Importing and format-converting OPD from R2024092402-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036768917330458 0.4592560159346961
# Importing and format-converting OPD from R2024092502-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.1403733171904395 0.4593337411557454
# Importing and format-converting OPD from R2024092802-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036389326222462 0.4594602756360255
# Importing and format-converting OPD from R2024093004-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14036819863869857 0.45936281989212074
# Importing and format-converting OPD from R2024100302-NRCA3_FP1-1.fits
# Backing out SI WFE and OTE field dependence at the WF sensing field point (NRCA3_FP1)
# 0.14037003407485232 0.45937746773884636

# %%
# For testing, print the resulting arrays to screen

# print(rmsWFE, fwhm_444, EE_444)

# %% [markdown]
# ## Plots and Analysis of Trends

# %%
# Fit a straight line (degree=1) to the points of EE vs. WFE for each filter.

# The function returns the coefficients of the polynomial,
# where p[0] is the slope (m) and p[1] is the y-intercept (b)

m_070, b_070 = np.polyfit(rmsWFE[0:len(EE_070)],EE_070, 1)
m_090, b_090 = np.polyfit(rmsWFE[0:len(EE_090)],EE_090, 1)
m_115, b_115 = np.polyfit(rmsWFE[0:len(EE_115)],EE_115, 1)
m_150, b_150 = np.polyfit(rmsWFE[0:len(EE_150)],EE_150, 1)
m_200, b_200 = np.polyfit(rmsWFE[0:len(EE_200)],EE_200, 1)
m_277, b_277 = np.polyfit(rmsWFE[0:len(EE_277)],EE_277, 1)
m_356, b_356 = np.polyfit(rmsWFE[0:len(EE_356)],EE_356, 1)
m_444, b_444 = np.polyfit(rmsWFE[0:len(EE_444)],EE_444, 1)

# Generate y-values for the fitted lines

EE_070_fit = (m_070 * rmsWFE[0:len(EE_070)]) + b_070
EE_090_fit = (m_090 * rmsWFE[0:len(EE_090)]) + b_090
EE_115_fit = (m_115 * rmsWFE[0:len(EE_115)]) + b_115
EE_150_fit = (m_150 * rmsWFE[0:len(EE_150)]) + b_150
EE_200_fit = (m_200 * rmsWFE[0:len(EE_200)]) + b_200
EE_277_fit = (m_277 * rmsWFE[0:len(EE_277)]) + b_277
EE_356_fit = (m_356 * rmsWFE[0:len(EE_356)]) + b_356
EE_444_fit = (m_444 * rmsWFE[0:len(EE_444)]) + b_444

# Print the slope divided by the EE for element [imin], which 
# has the lowest value of rmsWFE

print(f"FWHM_0, Ropt, EE_0, s_e/EE_0 for all filters") 
print(f"F070W: {fwhm_070[imin]} , {Ropt_070}, {EE_070[imin]} , {m_070/EE_070[imin]}")
print(f"F090W: {fwhm_090[imin]} , {Ropt_090}, {EE_090[imin]} , {m_090/EE_090[imin]}")
print(f"F115W: {fwhm_115[imin]} , {Ropt_115}, {EE_115[imin]} , {m_115/EE_115[imin]}")
print(f"F150W: {fwhm_150[imin]} , {Ropt_150}, {EE_150[imin]} , {m_150/EE_150[imin]}")
print(f"F200W: {fwhm_200[imin]} , {Ropt_200}, {EE_200[imin]} , {m_200/EE_200[imin]}")
print(f"F277W: {fwhm_277[imin]} , {Ropt_277}, {EE_277[imin]} , {m_277/EE_277[imin]}")
print(f"F356M: {fwhm_356[imin]} , {Ropt_356}, {EE_356[imin]} , {m_356/EE_356[imin]}")
print(f"F444W: {fwhm_444[imin]} , {Ropt_444}, {EE_444[imin]} , {m_444/EE_444[imin]}")
# Out:
# FWHM_0, Ropt, EE_0, s_e/EE_0 for all filters
# F070W: 0.02279252518159875 , 0.01742254182782119, 0.42127111386676175 , -0.010843301540142302
# F090W: 0.029451428624575393 , 0.022033625608343644, 0.49631833838809625 , -0.006803508239477984
# F115W: 0.03718515351829069 , 0.02724979841561603, 0.5497723089026361 , -0.004233142451298877
# F150W: 0.04833295033902534 , 0.03450544911927581, 0.5370628660824575 , -0.002493742258123833
# F200W: 0.06353565709485373 , 0.043899327903525374, 0.5301423465427262 , -0.0014765260618026701
# F277W: 0.08831738723971669 , 0.05797306495875029, 0.5295964765791895 , -0.0005657755203613763
# F356M: 0.11429686086268903 , 0.0710779137717131, 0.4862236724690275 , -0.00033048677421924845
# F444W: 0.14035144152726098 , 0.08252531420231378, 0.4599003009291639 , -0.00022366799616565188

# %%
# Create scatter plot of the results
# We divide the EE values and the linear fit by the value for array element 
# number imin, which has the lowest rmsWFE

plt.ylim(0.90,1.02)
plt.xlim(60.0,70.0)

plt.plot(rmsWFE[0:len(EE_444)],EE_444/EE_444[imin],'o',color='red')
plt.plot(rmsWFE[0:len(EE_444)],EE_444_fit/EE_444[imin],color='red',label='F444W')

plt.plot(rmsWFE[0:len(EE_356)],EE_356/EE_356[imin],'o',color='orange')
plt.plot(rmsWFE[0:len(EE_356)],EE_356_fit/EE_356[imin],color='orange',label='F356W')

plt.plot(rmsWFE[0:len(EE_277)],EE_277/EE_277[imin],'o',color='yellow')
plt.plot(rmsWFE[0:len(EE_277)],EE_277_fit/EE_277[imin],color='yellow',label='F277W')

plt.plot(rmsWFE[0:len(EE_200)],EE_200/EE_200[imin],'o',color='green')
plt.plot(rmsWFE[0:len(EE_200)],EE_200_fit/EE_200[imin],color='green',label='F200W')

plt.plot(rmsWFE[0:len(EE_150)],EE_150/EE_150[imin],'o',color='aquamarine')
plt.plot(rmsWFE[0:len(EE_150)],EE_150_fit/EE_150[imin],color='aquamarine',label='F150W')

plt.plot(rmsWFE[0:len(EE_115)],EE_115/EE_115[imin],'o',color='cyan')
plt.plot(rmsWFE[0:len(EE_115)],EE_115_fit/EE_115[imin],color='cyan',label='F115W')

plt.plot(rmsWFE[0:len(EE_090)],EE_090/EE_090[imin],'o',color='blue')
plt.plot(rmsWFE[0:len(EE_090)],EE_090_fit/EE_090[imin],color='blue', label='F090W')

plt.plot(rmsWFE[0:len(EE_070)],EE_070/EE_070[imin],'o',color='violet')
plt.plot(rmsWFE[0:len(EE_070)],EE_070_fit/EE_070[imin],color='violet',label='F070W')

plt.xlabel("OTE RMS WFE (nm)")
plt.ylabel("EE / EE$_{0}$ (R$_{opt}$)")
plt.title("Dependence of NIRCam Imaging EE on WFE from 03/31/24 to 10/03/24")
plt.grid(True)
plt.legend(loc='lower left', title='Filters', fontsize='small', frameon=True, framealpha=0.8)
plt.savefig("NIRCam_EE.jpg",dpi=300) 
plt.show()

# %% [markdown]
# ## Weighted Averages over different filter Usages

# %%
# To calculate weighted averages over the different filters, we
# specify usage fractions

f070 = 0.0265
f090 = 0.0648
f115 = 0.1325
f150 = 0.1357
f200 = 0.1405
f277 = 0.1658
f356 = 0.1358
f444 = 0.1984

# Calculate total sums

fstot = ( (f070*m_070/EE_070[imin]) + 
          (f090*m_090/EE_090[imin]) +
          (f115*m_115/EE_115[imin]) +
          (f150*m_150/EE_150[imin]) +
          (f200*m_200/EE_200[imin]) +
          (f277*m_277/EE_277[imin]) +
          (f356*m_356/EE_356[imin]) +
          (f444*m_444/EE_444[imin]) )
ftotNIRC = f070 + f090 + f115 + f150 + f200 + f277 + f356 + f444

seNIRC = fstot/ftotNIRC
print("overall NIRCam -s_e")
print(seNIRC,ftotNIRC)

# Now do separately for the SW and LW channels

fstotSW = ( (f070*m_070/EE_070[imin]) + 
            (f090*m_090/EE_090[imin]) +
            (f115*m_115/EE_115[imin]) +
            (f150*m_150/EE_150[imin]) +
            (f200*m_200/EE_200[imin]) )
ftotSW = f070 + f090 + f115 + f150 + f200

seSW = fstotSW/ftotSW
print("SW NIRCam -s_e")
print(seSW,ftotSW)

fstotLW = ( (f277*m_277/EE_277[imin]) +
            (f356*m_356/EE_356[imin]) +
            (f444*m_444/EE_444[imin]) )
ftotLW = f277 + f356 + f444

seLW = fstotLW/ftotLW
print("LW NIRCam -s_e")
print(seLW,ftotLW)
# Out:
# overall NIRCam -s_e
# -0.0020180203512938804 1.0
# SW NIRCam -s_e
# -0.00366991787127945 0.5
# LW NIRCam -s_e
# -0.00036612283130831096 0.5

# %%
# To actually calculate the weighted average with error bars, we do Monte-Carlo simulations

# Set uncertainty factor for all fractions

dffac = 0.25

# Set Gaussian sigma cutoff

sigcut = 3.0

# Set number of Monte Carlos

NMC = 1000000

# Set up arrays with random deviate fractions

dfar_070 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_090 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_115 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_150 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_200 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_277 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_356 = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dfar_444 = np.random.normal(loc=0.0, scale=1.0, size=NMC)

dfar_070 = np.clip(dfar_070, a_min=-1.0*sigcut, a_max=sigcut)
dfar_090 = np.clip(dfar_090, a_min=-1.0*sigcut, a_max=sigcut)
dfar_115 = np.clip(dfar_115, a_min=-1.0*sigcut, a_max=sigcut)
dfar_150 = np.clip(dfar_150, a_min=-1.0*sigcut, a_max=sigcut)
dfar_200 = np.clip(dfar_200, a_min=-1.0*sigcut, a_max=sigcut)
dfar_277 = np.clip(dfar_277, a_min=-1.0*sigcut, a_max=sigcut)
dfar_356 = np.clip(dfar_356, a_min=-1.0*sigcut, a_max=sigcut)
dfar_444 = np.clip(dfar_444, a_min=-1.0*sigcut, a_max=sigcut)

far_070  = (f070 * np.ones(NMC))  + (f070 * dffac * dfar_070)
far_090  = (f090 * np.ones(NMC))  + (f090 * dffac * dfar_090)
far_115  = (f115 * np.ones(NMC))  + (f115 * dffac * dfar_115)
far_150  = (f150 * np.ones(NMC))  + (f150 * dffac * dfar_150)
far_200  = (f200 * np.ones(NMC))  + (f200 * dffac * dfar_200)
far_277  = (f277 * np.ones(NMC))  + (f277 * dffac * dfar_277)
far_356  = (f356 * np.ones(NMC))  + (f356 * dffac * dfar_356)
far_444  = (f444 * np.ones(NMC))  + (f444 * dffac * dfar_444)

# Print some stats for debugging

# print(np.mean(dfar_070),np.min(dfar_070),np.max(dfar_070))

# %%
# Calculate weighted sums

# Calculate array of total sums

farstot = ( (far_070*m_070/EE_070[imin]) + 
            (far_090*m_090/EE_090[imin]) +
            (far_115*m_115/EE_115[imin]) +
            (far_150*m_150/EE_150[imin]) +
            (far_200*m_200/EE_200[imin]) +
            (far_277*m_277/EE_277[imin]) +
            (far_356*m_356/EE_356[imin]) +
            (far_444*m_444/EE_444[imin]) )
fartot = far_070 + far_090 + far_115 + far_150 + far_200 + far_277 + far_356 + far_444

# Now do separately for the SW and LW channels

farstotSW = ( (far_070*m_070/EE_070[imin]) + 
              (far_090*m_090/EE_090[imin]) +
              (far_115*m_115/EE_115[imin]) +
              (far_150*m_150/EE_150[imin]) +
              (far_200*m_200/EE_200[imin]) )
fartotSW = far_070 + far_090 + far_115 + far_150 + far_200

farstotLW = ( (far_277*m_277/EE_277[imin]) +
              (far_356*m_356/EE_356[imin]) +
              (far_444*m_444/EE_444[imin]) )
fartotLW = far_277 + far_356 + far_444

# Divide arrays to get weighted average estimated of s_e/EE_0

sar   = farstot/fartot
sarSW = farstotSW/fartotSW
sarLW = farstotLW/fartotLW

# Print statistics

dseNIRC = np.std(sar)
dseSW   = np.std(sarSW)
dseLW   = np.std(sarLW) 

print("Overall NIRCam -s_e (MCs)")
print(np.mean(sar),dseNIRC)
print("SW NIRCam -s_e (MCs)")
print(np.mean(sarSW),dseSW)
print("LW NIRCam -s_e (MCs)")
print(np.mean(sarLW),dseLW)
# Out:
# Overall NIRCam -s_e (MCs)
# -0.0020233408236195382 0.00017625327820321935
# SW NIRCam -s_e (MCs)
# -0.0036797940790700696 0.0002315887377770615
# LW NIRCam -s_e (MCs)
# -0.0003663320305608262 2.259605955430077e-05

# %% [markdown]
# ## Weighted Average over all contributing SI modes

# %%
# Now we want to use these averages to calculate the weighted average for all the contributing modes,
# as discussed in my TR. 

# Usage percentges of contributing modes (from Cycle 4 usage stats).
# I don't need to include the factor f_app in my TR (fraction of observations that are faint opoint sources),
# since its the same for all modes, and drops out of the average.

fNcamim   = 14.0
fNcamss   =  1.5
fNcamcoro =  2.0
fNissami  =  0.2
fNspecfix =  3.5
fNspecmos = 18.9

# sums

fNsetot = ( (fNcamim*seSW) + (fNcamss*seSW) + (fNcamcoro*seLW/2.0) + (fNissami*seLW) + (fNspecfix*seNIRC/2.0) + (fNspecmos*seNIRC/2.0) )
fNtot   = ( (fNcamim) + (fNcamss) + (fNcamcoro) + (fNissami) + (fNspecfix) + (fNspecmos))

seav = fNsetot / fNtot
print("combined modes -s_e")
print(seav)
# Out:
# combined modes -s_e
# -0.0019931397091494493

# %%
# Now we do Monte-carlo simulations to calculate the error bar

# Set Gaussian sigma cutoff

sigcut = 3.0

# Set number of Monte Carlos

NMC = 1000000

# Set up arrays with random deviates

dsearSW   = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dsearLW   = np.random.normal(loc=0.0, scale=1.0, size=NMC)

dsearSW   = np.clip(dsearSW, a_min=-1.0*sigcut, a_max=sigcut)
dsearLW   = np.clip(dsearLW, a_min=-1.0*sigcut, a_max=sigcut)

searSW     = (seSW   * np.ones(NMC)) + (dseSW   * dsearSW)
searLW     = (seLW   * np.ones(NMC)) + (dseLW   * dsearLW)

# Calculate the overall NIRCam se array from the combination of the SW and LW filters

searNIRC   = ((ftotSW*searSW) + (ftotLW*searLW)) / (ftotSW+ftotLW)

# Now calculate the combination of all the modes

fNsetot = ( (fNcamim*searSW) + (fNcamss*searSW) + (fNcamcoro*searLW/2.0) + 
            (fNissami*searLW) + (fNspecfix*searNIRC/2.0) + (fNspecmos*searNIRC/2.0) )
fNtot   = ( (fNcamim) + (fNcamss) + (fNcamcoro) + (fNissami) + (fNspecfix) + (fNspecmos))

# Get the mean and standard deviation of the Monte-Carlos

dseNIRC = np.std(sar)
dseSW   = np.std(sarSW)
dseLW   = np.std(sarLW)

secomb  = np.mean(fNsetot/fNtot)
dsecomb = np.std(fNsetot/fNtot)

print("combined modes -s_e (MCs)")
print(secomb,dsecomb)
# Out:
# combined modes -s_e (MCs)
# -0.001993128484403641 0.00012166495475053749

# %% [markdown]
# ## WFC Threshold

# %%
# Hardcode results for testing
# secomb  = -0.001753134620044826
# dsecomb = 0.0002283018319913573

# Now we can use this with other numbers to calculate the WFC threshold

# added time for WFC in days

dTc = (1/(24.0*60.0)) * (98.0 - 51.0)

# slope of WFE drift in nm/day

sw  = 0.0862
dsw = 0.0513

# Relevant wall-clock fraction

xi  = 0.222876
dxi = 0.063155

# Calculate threshold in nm

drmsWFE = math.sqrt(dTc*sw/(-2.0*xi*secomb))
print("WFC threshold in nm")
print (drmsWFE)

# Calculate cadence in days
dTWFC = drmsWFE / sw
print("WFC cadence in days")
print (dTWFC)

# Calculate integrated WFE
dIW = 0.5*drmsWFE*dTWFC
print("Integrated WFE in nm day")
print (dIW)
# Out:
# WFC threshold in nm
# 1.779536981339758
# WFC cadence in days
# 20.64428052598327
# Integrated WFE in nm day
# 18.368630324569708

# %%
# Now perform Monte-carlos to generate error bars

# Set Gaussian sigma cutoff

sigcut  = 3.0
sigcutw = 1.0

# Set number of Monte Carlos

NMC = 1000000

# Set up arrays with random deviates

dxiar  = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dxiar  = np.clip(dxiar, a_min=-1.0*sigcut, a_max=sigcut)
xiar   = (xi*np.ones(NMC)) + (dxi*dxiar)

dswar  = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dswar  = np.clip(dswar, a_min=-1.0*sigcutw, a_max=sigcutw)
swar   = (sw*np.ones(NMC)) + (dsw*dswar)

dsear  = np.random.normal(loc=0.0, scale=1.0, size=NMC)
dsear  = np.clip(dsear, a_min=-1.0*sigcut, a_max=sigcut)
sear   = (secomb*np.ones(NMC)) + (dsecomb*dsear)

drmsWFEar = np.sqrt(dTc*swar/(-2.0*xiar*sear))
print("WFC threshold in nm (MCs)")
print (np.mean(drmsWFEar),np.std(drmsWFEar))

dTWFCar = drmsWFEar / swar
print("WFC cadence in days (MCs)")
print (np.mean(dTWFCar),np.std(dTWFCar)) 

dIWar = 0.5*drmsWFEar*dTWFCar
print("Integrated WFE in nm day")
print (np.mean(dIWar),np.std(dIWar))
# Out:
# WFC threshold in nm (MCs)
# 1.8024129764394667 0.5377944558209147
# WFC cadence in days (MCs)
# 23.363447856086054 7.464443087299507
# Integrated WFE in nm day
# 20.526669592522506 9.184013730733856
